# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas_profiling as pp
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
xls_file = pd.ExcelFile('Result15.xlsx')
df = xls_file.parse('Sheet1')
df.fillna(0, inplace = True)
values=df['Payment Status']
label_encoder=LabelEncoder()
df['payment_Status']=label_encoder.fit_transform(values)
df
# Out:
#                        CASE_KEY  Payment Status  Acc. Doc. Baseline Date  \
# 0      110US0101001389412018001  Early Payments                      1.0
# 1      110US0101001405392019001  Early Payments                      1.0
# 2      110US0111005391342018001    Late Payment                      1.0
# 3      110US0111005872702019001  Early Payments                      1.0
# 4      110US0111005872722019001  Early Payments                      1.0
# ...                         ...             ...                      ...
# 17372  111US0111111348632018001  Early Payments                      0.0
# 17373  111US0111111348652018001  Early Payments                      0.0
# 17374  111US0111111348672018001  Early Payments                      0.0
# 17375  111US0111111348692018001  Early Payments                      0.0
# 17376  111US0111111348712018001  Early Payments                      0.0
#
#        Acc. Doc. Baseline Date Changed  Acc. Doc. Cash Discount Days Changed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17377 entries, 0 to 17376
# Data columns (total 14 columns):
# CASE_KEY                                              17377 non-null object
# Payment Status                                        17377 non-null object
# Acc. Doc. Baseline Date                               17377 non-null float64
# Acc. Doc. Baseline Date Changed                       17377 non-null float64
# Acc. Doc. Cash Discount Days Changed                  17377 non-null float64
# Acc. Doc. Cleared                                     17377 non-null float64
# Acc. Doc. Due Date Passed                             17377 non-null float64
# Acc. Doc. For Payment Block Removed                   17377 non-null float64
# Accounting document Credit Memo Correction created    17377 non-null float64
# Accounting document Credit Memo line created          17377 non-null float64
# Accounting document Invoice line created              17377 non-null float64
# ...

# %%
df['payment_Status']=df['payment_Status'].astype("str")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17377 entries, 0 to 17376
# Data columns (total 14 columns):
# CASE_KEY                                              17377 non-null object
# Payment Status                                        17377 non-null object
# Acc. Doc. Baseline Date                               17377 non-null float64
# Acc. Doc. Baseline Date Changed                       17377 non-null float64
# Acc. Doc. Cash Discount Days Changed                  17377 non-null float64
# Acc. Doc. Cleared                                     17377 non-null float64
# Acc. Doc. Due Date Passed                             17377 non-null float64
# Acc. Doc. For Payment Block Removed                   17377 non-null float64
# Accounting document Credit Memo Correction created    17377 non-null float64
# Accounting document Credit Memo line created          17377 non-null float64
# Accounting document Invoice line created              17377 non-null float64
# ...

# %%
df['Payment Status'].value_counts()
# Out:
# Paid On time      8966
# Early Payments    7645
# Late Payment       766
# Name: Payment Status, dtype: int64

# %%
df.drop(['CASE_KEY','Payment Status'],axis=1,inplace=True)
df=df.astype("int64")

# %%
#df['order'] = df['Acc. Doc. Baseline Date'].map(str) + df['Acc. Doc. Baseline Date Changed'].map(str)
df['order'] = (df['Acc. Doc. Baseline Date'].astype(str) + df['Acc. Doc. Baseline Date Changed'].astype(str) + 
                df['Acc. Doc. Cash Discount Days Changed'].astype(str)+df['Acc. Doc. Cleared'].astype(str)+
                df['Acc. Doc. Due Date Passed'].astype(str) + df['Acc. Doc. For Payment Block Removed'].astype(str)+
                df['Accounting document Credit Memo Correction created'].astype(str) + df['Accounting document Credit Memo Correction created'].astype(str) +
                df['Accounting document Credit Memo line created'].astype(str) + df['Accounting document Invoice line created'].astype(str)+
                df['Accounting document Invoice reversal created'].astype(str) + df['Vendor Creates Invoice'].astype(str))
df
# Out:
#        Acc. Doc. Baseline Date  Acc. Doc. Baseline Date Changed  \
# 0                            1                                0
# 1                            1                                0
# 2                            1                                3
# 3                            1                                0
# 4                            1                                0
# ...                        ...                              ...
# 17372                        0                                0
# 17373                        0                                0
# 17374                        0                                0
# 17375                        0                                0
# 17376                        0                                0
#
#        Acc. Doc. Cash Discount Days Changed  Acc. Doc. Cleared  \
# 0                                         0                  3
# 1                                         0                  4
# ...

# %%
df=df.astype("int64")
print(len(df.columns))
print(df.columns)
print(df.info())
# Out:
# 13
# Index(['Acc. Doc. Baseline Date', 'Acc. Doc. Baseline Date Changed',
#        'Acc. Doc. Cash Discount Days Changed', 'Acc. Doc. Cleared',
#        'Acc. Doc. Due Date Passed', 'Acc. Doc. For Payment Block Removed',
#        'Accounting document Credit Memo Correction created',
#        'Accounting document Credit Memo line created',
#        'Accounting document Invoice line created',
#        'Accounting document Invoice reversal created',
#        'Vendor Creates Invoice', 'payment_Status', 'order'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17377 entries, 0 to 17376
# Data columns (total 13 columns):
# Acc. Doc. Baseline Date                               17377 non-null int64
# Acc. Doc. Baseline Date Changed                       17377 non-null int64
# Acc. Doc. Cash Discount Days Changed                  17377 non-null int64
# Acc. Doc. Cleared                                     17377 non-null int64
# ...

# %%
df['Acc. Doc. Baseline Date'].value_counts()
# Out:
# 1    8774
# 0    8601
# 2       2
# Name: Acc. Doc. Baseline Date, dtype: int64

# %%
df['payment_Status'].value_counts()
# Out:
# 2    8966
# 0    7645
# 1     766
# Name: payment_Status, dtype: int64

# %%
df['Acc. Doc. Baseline Date'].plot.hist(bins=10,figsize=(8,4))

# %%
df['Vendor Creates Invoice'].plot.hist(bins=15,figsize=(8,4))

# %%
df.corr()
# Out:
#                                                     Acc. Doc. Baseline Date  \
# Acc. Doc. Baseline Date                                            1.000000
# Acc. Doc. Baseline Date Changed                                    0.130776
# Acc. Doc. Cash Discount Days Changed                               0.350773
# Acc. Doc. Cleared                                                  0.962825
# Acc. Doc. Due Date Passed                                          0.972076
# Acc. Doc. For Payment Block Removed                                0.481706
# Accounting document Credit Memo Correction created                 0.007505
# Accounting document Credit Memo line created                       0.015011
# Accounting document Invoice line created                          -0.998739
# Accounting document Invoice reversal created                       0.007505
# Vendor Creates Invoice                                             0.999482
# ...

# %%
df1=df.copy()
#df1
df1 = df1.astype(str)
#df1['Acc. Doc. Baseline Date']=df1['Acc. Doc. Baseline Date'].astype(str)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17377 entries, 0 to 17376
# Data columns (total 14 columns):
# CASE_KEY                                              17377 non-null object
# Payment Status                                        17377 non-null object
# Acc. Doc. Baseline Date                               17377 non-null object
# Acc. Doc. Baseline Date Changed                       17377 non-null object
# Acc. Doc. Cash Discount Days Changed                  17377 non-null object
# Acc. Doc. Cleared                                     17377 non-null object
# Acc. Doc. Due Date Passed                             17377 non-null object
# Acc. Doc. For Payment Block Removed                   17377 non-null object
# Accounting document Credit Memo Correction created    17377 non-null object
# Accounting document Credit Memo line created          17377 non-null object
# Accounting document Invoice line created              17377 non-null object
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,linewidths=2)

# %%
#df.describe(include=['object', 'bool'])

# %%
sns.countplot(x='Acc. Doc. Baseline Date', hue='payment_Status', data=df);

# %%
df1=df[(df['payment_Status'] == 1)]
sns.countplot(x='order', hue='payment_Status', data=df1);

# %%
sns.countplot(x='order', hue='payment_Status', data=df);

# %%
df
# Out:
#        Acc. Doc. Baseline Date  Acc. Doc. Baseline Date Changed  \
# 0                            1                                0
# 1                            1                                0
# 2                            1                                3
# 3                            1                                0
# 4                            1                                0
# ...                        ...                              ...
# 17372                        0                                0
# 17373                        0                                0
# 17374                        0                                0
# 17375                        0                                0
# 17376                        0                                0
#
#        Acc. Doc. Cash Discount Days Changed  Acc. Doc. Cleared  \
# 0                                         0                  3
# 1                                         0                  4
# ...

# %%
plt.figure(figsize=(10,5)) 
#sns.countplot(x='order', hue='payment_Status', data=df);
df1=df[(df['payment_Status'] == 1)]
ax = sns.countplot(x="order", hue='payment_Status', data=df1)
plt.legend(loc='upper right')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5)) 
#sns.countplot(x='order', hue='payment_Status', data=df);
df1=df[(df['payment_Status'] == 1)]
ax = sns.countplot(x="order", hue='payment_Status', data=df)
plt.legend(loc='upper right')
ax.set_xticklabels(ax.get_xticklabels(), rotation=50, ha="right")
plt.tight_layout()
plt.show()

# %%
#pd.crosstab(df['Payment Status'], df['Vendor Creates Invoice'], margins=True)
#train_modified.to_csv("train_ready_for_model_loan.csv",index=False)

# %%
df1=df[(df['payment_Status'] == 1)]
df1['order'].value_counts()
# Out:
# 100             378
# 100430000002    288
# 103564000002     80
# 104674000002      9
# 130755000002      2
# 104765003002      2
# 240786000001      2
# 100540003002      1
# 103540000002      1
# 103755000002      1
# 200               1
# 104866003002      1
# Name: order, dtype: int64

# %%
df1=df[(df['payment_Status'] == 0)]
df1['order'].value_counts()
# Out:
# 100             3749
# 103450000002    1458
# 100340000002    1147
# 100453000002     586
# 130564000002     284
# 104563000002     193
# 104674000002     190
# 103564000002      26
# 200                8
# 103675000002       2
# 100000000002       1
# 100450330062       1
# Name: order, dtype: int64

# %%
df1=df[(df['payment_Status'] == 2)]
df1['order'].value_counts()
# Out:
# 100             4465
# 100340000002    2501
# 100453000002    1708
# 100563000002     284
# 103450000002       8
# Name: order, dtype: int64

# %%
df['payment_Status'].value_counts()
# Out:
# 2    8966
# 0    7645
# 1     766
# Name: payment_Status, dtype: int64

# %%
pp.ProfileReport(df)

# %%
y=['payment_Status']
x=[i for i in df if i not in y]
x
# Out:
# ['Acc._Doc._Baseline_Date',
#  'Acc._Doc._Baseline_Date_Changed',
#  'Acc._Doc._Cash_Discount_Days_Changed',
#  'Acc._Doc._Cleared',
#  'Acc._Doc._Due_Date_Passed',
#  'Acc._Doc._For_Payment_Block_Removed',
#  'Accounting_document_Credit_Memo_Correction_created',
#  'Accounting_document_Credit_Memo_line_created',
#  'Accounting_document_Invoice_line_created',
#  'Accounting_document_Invoice_reversal_created',
#  'Vendor_Creates_Invoice',
#  'order']

# %%
x=df.iloc[:,:-3]
y=df.iloc[:,-2]
x
# Out:
#        Acc._Doc._Baseline_Date  Acc._Doc._Baseline_Date_Changed  \
# 0                            1                                0
# 1                            1                                0
# 2                            1                                3
# 3                            1                                0
# 4                            1                                0
# ...                        ...                              ...
# 17372                        0                                0
# 17373                        0                                0
# 17374                        0                                0
# 17375                        0                                0
# 17376                        0                                0
#
#        Acc._Doc._Cash_Discount_Days_Changed  Acc._Doc._Cleared  \
# 0                                         0                  3
# 1                                         0                  4
# ...

# %%
#x_train, x_test, y_train, y_test = train_test_split(df[x], df[y], test_size=0.3, random_state=0)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=logreg.predict(x_test)

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.66

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = LogisticRegression()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, x_train, y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy: 0.656

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[ 619    0 1627]
#  [  33   97  120]
#  [   3    0 2715]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.28      0.43      2246
#            1       1.00      0.39      0.56       250
#            2       0.61      1.00      0.76      2718
#
#     accuracy                           0.66      5214
#    macro avg       0.85      0.55      0.58      5214
# weighted avg       0.77      0.66      0.60      5214

# %%
from sklearn.ensemble import RandomForestClassifier
logreg=RandomForestClassifier(n_estimators=200,max_depth=15,min_samples_leaf=30)
logreg.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=15, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=30, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred=logreg.predict(x_test)

# %%
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.66

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[ 613    6 1627]
#  [   6  124  120]
#  [   3    0 2715]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.27      0.43      2246
#            1       0.95      0.50      0.65       250
#            2       0.61      1.00      0.76      2718
#
#     accuracy                           0.66      5214
#    macro avg       0.85      0.59      0.61      5214
# weighted avg       0.79      0.66      0.61      5214

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-8334f36e46b2> in <module>
#       1 from sklearn.metrics import roc_auc_score
#       2 from sklearn.metrics import roc_curve
# ----> 3 logit_roc_auc = roc_auc_score(y_test, y_pred,average="weighted")
#       4 fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(x_test)[:,1])
#       5 plt.figure()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
# ...

# %%
plt.scatter(x_train[:,2], x_train[:, 3], c=y_train, alpha=0.5)
plt.xlabel("Petal Length (cm)"); plt.ylabel("Petal Width (cm)")
for theta in [thetas[0],thetas[2]]:
    j = np.array([x_train[:, 2].min(), x_train[:, 2].max()])
    k = -(j * theta[1] + theta[0]) / theta[2]
    plt.plot(j, k, color='k', linestyle="--")
